# %% [markdown]
# <a href="https://colab.research.google.com/github/DFelton88/Python-Coding/blob/master/Pandas_Assignment_1_9_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5b9364e5-efad-495f-8016-1c6aba4d838f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b9364e5-efad-495f-8016-1c6aba4d838f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cars.csv to cars.csv

# %%
df = pd.read_csv('cars.csv')

# %%
#Extract the first 5 rows of the dataframe
df.head(5)
# Out:
#    id first_name    last_name  ...   car_model car_model_year            car_vin
# 0   1      Elsey    MacEnelly  ...     Sunfire           2005  JN1AV7ARXFM870659
# 1   2        Web      Balmann  ...      Accent           1998  4F2CY0C79BK404159
# 2   3       Abey    Bernardet  ...          ES           1993  SCFFDAAE1CG604846
# 3   4      Adler  McGillecole  ...  Rendezvous           2002  WAUVF78K39A869814
# 4   5        Ola       Sparry  ...    Frontier           2001  1N6AA0CJ5DN998948
#
# [5 rows x 10 columns]

# %%
#Extract the first 25 rows
df.head(25)
# Out:
#     id first_name  ... car_model_year            car_vin
# 0    1      Elsey  ...           2005  JN1AV7ARXFM870659
# 1    2        Web  ...           1998  4F2CY0C79BK404159
# 2    3       Abey  ...           1993  SCFFDAAE1CG604846
# 3    4      Adler  ...           2002  WAUVF78K39A869814
# 4    5        Ola  ...           2001  1N6AA0CJ5DN998948
# 5    6     Nappie  ...           2011  WVWAP7AN1EE229042
# 6    7      Alysa  ...           2005  WBABN53452P450093
# 7    8      Bruce  ...           2007  1FMEU3DE6AU441345
# 8    9  Annabella  ...           1993  WBAVT73518F106735
# 9   10      Shane  ...           2006  1GTN1TEX8CZ146236
# 10  11      Irene  ...           1997  WBSWL93568P548528
# 11  12      Richy  ...           2001  JN1AY1AR2DM444501
# 12  13     Terrel  ...           1993  1D7RB1GT2BS183387
# 13  14      Pyotr  ...           2006  WBABD33456P771225
# 14  15     Isiahi  ...           2004  WAUMF78K99N721171
# ...

# %%
#Extract the last 5 rows of the dataframe
df.tail(5)
# Out:
#        id first_name  ... car_model_year            car_vin
# 995   996  Ethelbert  ...           1999  1N6AA0CC8DN240412
# 996   997       Yvon  ...           2000  WAUJC68E24A901432
# 997   998      Onfre  ...           1995  WAUDT48H05K333740
# 998   999   Vivianne  ...           2007  WAUBFAFL6AA707045
# 999  1000      Lisha  ...           2013  SCFAD22343K508879
#
# [5 rows x 10 columns]

# %%
#Create a new column named 'full_name' by combining the first_name and last_name columns
df.rename(columns={'first_name':'full_name','last_name':''}, inplace=True)

# %%
#Rename the 'car_vin' column to 'vin_number'
df.rename(columns={'car_vin':'vin_number'}, inplace=True)

# %%
#Find how many non null values are in each column
df.isnull().sum().sum()
# Out:
# 119

# %%
#Clone the dataframe and rename your new dataframe 'df2'
df.copy(deep=True)
# Out:
#        id  full_name  ... car_model_year         vin_number
# 0       1      Elsey  ...           2005  JN1AV7ARXFM870659
# 1       2        Web  ...           1998  4F2CY0C79BK404159
# 2       3       Abey  ...           1993  SCFFDAAE1CG604846
# 3       4      Adler  ...           2002  WAUVF78K39A869814
# 4       5        Ola  ...           2001  1N6AA0CJ5DN998948
# ..    ...        ...  ...            ...                ...
# 995   996  Ethelbert  ...           1999  1N6AA0CC8DN240412
# 996   997       Yvon  ...           2000  WAUJC68E24A901432
# 997   998      Onfre  ...           1995  WAUDT48H05K333740
# 998   999   Vivianne  ...           2007  WAUBFAFL6AA707045
# 999  1000      Lisha  ...           2013  SCFAD22343K508879
#
# [1000 rows x 10 columns]

# %%
df.rename(columns={"df.copy": "df2"})
# Out:
#        id  full_name  ... car_model_year         vin_number
# 0       1      Elsey  ...           2005  JN1AV7ARXFM870659
# 1       2        Web  ...           1998  4F2CY0C79BK404159
# 2       3       Abey  ...           1993  SCFFDAAE1CG604846
# 3       4      Adler  ...           2002  WAUVF78K39A869814
# 4       5        Ola  ...           2001  1N6AA0CJ5DN998948
# ..    ...        ...  ...            ...                ...
# 995   996  Ethelbert  ...           1999  1N6AA0CC8DN240412
# 996   997       Yvon  ...           2000  WAUJC68E24A901432
# 997   998      Onfre  ...           1995  WAUDT48H05K333740
# 998   999   Vivianne  ...           2007  WAUBFAFL6AA707045
# 999  1000      Lisha  ...           2013  SCFAD22343K508879
#
# [1000 rows x 10 columns]

# %%
#Remove all missing values in df2
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Out:
#        id  full_name  ... car_model_year         vin_number
# 0       1      Elsey  ...           2005  JN1AV7ARXFM870659
# 1       2        Web  ...           1998  4F2CY0C79BK404159
# 3       4      Adler  ...           2002  WAUVF78K39A869814
# 4       5        Ola  ...           2001  1N6AA0CJ5DN998948
# 5       6     Nappie  ...           2011  WVWAP7AN1EE229042
# ..    ...        ...  ...            ...                ...
# 995   996  Ethelbert  ...           1999  1N6AA0CC8DN240412
# 996   997       Yvon  ...           2000  WAUJC68E24A901432
# 997   998      Onfre  ...           1995  WAUDT48H05K333740
# 998   999   Vivianne  ...           2007  WAUBFAFL6AA707045
# 999  1000      Lisha  ...           2013  SCFAD22343K508879
#
# [881 rows x 10 columns]
